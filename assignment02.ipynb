# %% [markdown]
# # This is assignment02
#
# ## Name : Jaehyun Lim
#
# ## Student ID : 20145450

# %% [markdown]
# ## import packages for plotting graphs and manipulating data:

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Define the function

# %% [markdown]
# $$ f(x) = sin(x)*x $$

# %%
def Function(x):
    f = np.sin(x) * x
    return f

# %% [markdown]
# ## define the derivative of my function

# %% [markdown]
# $$ f'(x) = cos(x)*x + sin(x) $$

# %%
def DerivativeFunction(x):
    Df = np.cos(x) * x + np.sin(x)
    return Df

# %% [markdown]
# ## define the function of tangent line

# %% [markdown]
# $$ y-f(a)=f'(a)(x-a)$$

# %%
def Slope_of_tangent_line(a):
    St = DerivativeFunction(a)*(x-a) + Function(a)
    return St

# %% [markdown]
# ## define the domain of the function

# %% [markdown]
# $$ x = [-10 : 0.01 : 10] $$

# %%
x = np.arange(-10, 10, 0.01)

# %% [markdown]
# ## compute the graph

# %%
fx = Function(x)
Dfx = DerivativeFunction(x)

# %% [markdown]
# ## Pick 3 points in the domain

# %%
p1 = Slope_of_tangent_line(1)
p2 = Slope_of_tangent_line(-5)
p3 = Slope_of_tangent_line(8)

# %% [markdown]
# ## plot the graphs for the function, its derivative, Taylor approximation at the given points

# %%
plt.figure(1)

plt.plot(x, fx, 'b', label="function")
plt.plot(x, Dfx, 'r', label="derivative")
plt.plot(x, p1, 'g--', label="p1")
plt.plot(x, p2, 'y--', label="p2")
plt.plot(x, p3, 'm--', label="p3")

plt.legend(loc='best')
plt.show()
